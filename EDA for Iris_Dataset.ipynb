# %% [raw]
# # Problem statement
#
# Exploratory Data Analysis

# %% [markdown]
# # <font color = 'green'>Importing required libraries

# %%
# for dataframe manipulation
import pandas as pd

#for basic numerical operations
import numpy as np

# for visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# for missing null values
import missingno as mno

# setting up the background style for plots
plt.style.use('fivethirtyeight')

#ignoring warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # <font color = 'green'>Reading Iris dataset

# %%
df = pd.read_csv('C:/Users/rayah/OneDrive/Desktop/INSOFE_PY_ML/Iris_dataset/Iris.csv')

# %%
# checking data frame type

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# top 5 rows of dataset

df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# bottom 5 rows of dataset

df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
# shape of data

df.shape
# Out:
# (150, 6)

# %%
# columns names of data

df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
# Dtypes of columns

df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
# info of data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# stats for numeric data

df.describe(include='float64').style.background_gradient(cmap='magma')
# Out:
# <style type="text/css">
# #T_d09e3_row0_col0, #T_d09e3_row0_col1, #T_d09e3_row0_col2, #T_d09e3_row0_col3 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_d09e3_row1_col0, #T_d09e3_row5_col0 {
#   background-color: #030312;
#   color: #f1f1f1;
# }
# #T_d09e3_row1_col1, #T_d09e3_row1_col2, #T_d09e3_row4_col1, #T_d09e3_row5_col1, #T_d09e3_row6_col1, #T_d09e3_row7_col3 {
#   background-color: #020109;
#   color: #f1f1f1;
# }
# #T_d09e3_row1_col3, #T_d09e3_row2_col2, #T_d09e3_row2_col3, #T_d09e3_row4_col2 {
#   background-color: #010005;
#   color: #f1f1f1;
# }
# #T_d09e3_row2_col0, #T_d09e3_row2_col1, #T_d09e3_row3_col2, #T_d09e3_row3_col3, #T_d09e3_row4_col3 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_d09e3_row3_col0, #T_d09e3_row5_col2 {
#   background-color: #02020b;
#   color: #f1f1f1;
# }
# #T_d09e3_row3_col1, #T_d09e3_row5_col3, #T_d09e3_row6_col3 {
#   background-color: #010106;
#   color: #f1f1f1;
# }
# #T_d09e3_row4_col0, #T_d09e3_row6_col2 {
# ...

# %%
# stats for category data

df.describe(include='object')
# Out:
#             Species
# count           150
# unique            3
# top     Iris-setosa
# freq             50

# %%
# drop unwanted column in data

df1 = df.drop('Id',axis=1) #bcz there is no correlation

# %%
# shape of data after dropping columns

df1.shape
# Out:
# (150, 5)

# %%
# check the correlation between variables/features

sns.heatmap(df1.corr(),fmt='0.2f',annot=True,linewidths=2,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # <font color = 'red'>Cleaning The data

# %%
# check the data has null values/not
# visualize the missing values

mno.bar(df1,color='blue',sort='ascending')
plt.title('Checking missing value',fontsize=10)
plt.show()

# %%
# checking null values

df1.isna().sum() #it seems there is no null values in data
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# checking the unique values

df1.nunique()
# Out:
# SepalLengthCm    35
# SepalWidthCm     23
# PetalLengthCm    43
# PetalWidthCm     22
# Species           3
# dtype: int64

# %%
# converting the columns into apprapriate data type

df1['Species'] =  df1.Species.astype('category')

# %%
# again check the dtypes of data

df1.dtypes
# Out:
# SepalLengthCm     float64
# SepalWidthCm      float64
# PetalLengthCm     float64
# PetalWidthCm      float64
# Species          category
# dtype: object

# %%
# count plot for Species

sns.countplot(df['Species'],palette='pink')
plt.show() #by seeing this we can say that data is well balanced

# %% [markdown]
# # <font color = 'green'>correlation B/w Features using Scatter plot

# %%
# check the features correlation

plt.scatter(x= df1['SepalLengthCm'],y=df['SepalWidthCm'])
plt.show()  # there is no correlation between these two variables

# %%
plt.scatter(x= df1['SepalLengthCm'],y=df['PetalLengthCm'])
plt.show()  # there is a correlation between these two variables

# %%
plt.scatter(x= df1['SepalLengthCm'],y=df['PetalWidthCm'])
plt.show()  # there is a correlation between these two variables

# %%
plt.scatter(x= df1['SepalWidthCm'],y=df['SepalLengthCm'])
plt.show()  # there is no correlation between these two variables

# %%
plt.scatter(x= df1['SepalWidthCm'],y=df['PetalLengthCm'])
plt.show()  # there is no correlation between these two variables

# %%
plt.scatter(x= df1['SepalWidthCm'],y=df['PetalWidthCm'])
plt.show()  # there is no correlation between these two variables

# %%
plt.scatter(x= df1['PetalLengthCm'],y=df['SepalLengthCm'])
plt.show()  # there is a correlation between these two variables

# %%
plt.scatter(x= df1['PetalLengthCm'],y=df['SepalWidthCm'])
plt.show()  # there is no correlation between these two variables

# %%
plt.scatter(x= df1['PetalLengthCm'],y=df['PetalWidthCm'])
plt.show()  # there is a correlation between these two variables

# %%
plt.scatter(x= df1['PetalWidthCm'],y=df['SepalLengthCm'])
plt.show()  # there is a correlation between these two variables

# %%
plt.scatter(x= df1['PetalWidthCm'],y=df['SepalWidthCm'])
plt.show()  # there is no correlation between these two variables

# %%
plt.scatter(x= df1['PetalWidthCm'],y=df['PetalLengthCm'])
plt.show()  # there is a correlation between these two variables

# %% [markdown]
# # <font color = 'green'>Dropping the SepalWidthcm in dataset bcz no correlation

# %%
df2 = df1.drop('SepalWidthCm',axis=1)

# %%
# again checking the correlation between features

sns.heatmap(df2.corr(),annot=True,fmt='0.2f',linewidth=2,cmap='magma')
# Out:
# <AxesSubplot:>

# %% [raw]
# ### I found SepalLengthCm, PetalLengthCm, PetalWidthCm these columns have high correlation and these will classify the Species accuratly.
#
# but what about SepalWidthCm........
